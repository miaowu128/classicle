# %%
import requests
from lxml import html
url='https://atlas.emory.edu/' #需要爬数据的网址
page=requests.Session().get(url) 
# tree=html.fromstring(page.text) 
tree=html.fromstring(page.content)
# result=tree.xpath('//div[@class="text col-3 detail-courseinfo margin--tiny text--semibold text--huge"]//div[@class="dtl-course-code"]/text()') #获取需要的数据                  
# result=tree.xpath('//html/body/main/div[3]/div/div[2]/div[1]/div[1]/div[1]/text()')
# result=tree.xpath('//html//body//main//div[3]//div//div[2]//div[1]//div[1]//div[1]/text()')                  

# result=tree.xpath('//html//body//main//div[1]//div//div[1]//h2/text()')   
result=tree.xpath('//body/main/div[2]/div[1]/div[1]/div/h2/text()')    
# result=tree.xpath('//body/main/div[2]/div[1]/div[1]/div/p/text()') 
# result=tree.xpath('//body/main/div[2]/div/div[3]/div[1]/a/span[1]/span[2]/text()') 
print(result)
# Out:
# ['Welcome to the Emory University Course Atlas']

# %%
print(page.content)
# Out:
# b'<!doctype html>\n<html lang="en" dir="ltr">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta name="description" content="Search Classes">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no"/>\n\t\t<title>Search Classes</title>\n\t\t<link rel="stylesheet" href="/js/lfjs.css">\n\t\t<link rel="stylesheet" href="/fonts/font-awesome/font-awesome.min.css">\n\t\t<link rel="stylesheet" href="fose.css?1600721789299">\n\t\t<script>\n\t\tvar foseConfig = {\n\t\t\tapiURL: "api/?page=fose",\n\t\t\tcontext: "fose",\n\t\t\tcanCreateCart: true,\n\t\t\ttextAPIError: "Sorry, we were unable to process your request",\n\t\t\ttextLoading: "Loading...",\n\t\t\ttextSearching: "Searching...",\n\t\t\ttextNotOffered: "This course is not currently being offered",\n\t\t\ttextTooBroad: "Search too broad, please use the search fields to narrow your results",\n\t\t\ttextValueVaries: "Varies by section",\n\t\t\ttextAmbiguousCartTerm: "To view your primary
# ...

# %%
print(html.tostring(tree, pretty_print=True))
# Out:
# b'<html lang="en" dir="ltr">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta name="description" content="Search Classes">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n\t\t<title>Search Classes</title>\n\t\t<link rel="stylesheet" href="/js/lfjs.css">\n\t\t<link rel="stylesheet" href="/fonts/font-awesome/font-awesome.min.css">\n\t\t<link rel="stylesheet" href="fose.css?1600721789299">\n\t\t<script>\n\t\tvar foseConfig = {\n\t\t\tapiURL: "api/?page=fose",\n\t\t\tcontext: "fose",\n\t\t\tcanCreateCart: true,\n\t\t\ttextAPIError: "Sorry, we were unable to process your request",\n\t\t\ttextLoading: "Loading...",\n\t\t\ttextSearching: "Searching...",\n\t\t\ttextNotOffered: "This course is not currently being offered",\n\t\t\ttextTooBroad: "Search too broad, please use the search fields to narrow your results",\n\t\t\ttextValueVaries: "Varies by section",\n\t\t\ttextAmbiguousCartTerm: "To view your primary cart, please sele
# ...

# %%
document.querySelector("body")
/html/body
/html/body/main/div[3]/div/div[2]/div[1]/div[1]/div[1]
document.querySelector("body > main > div.panel.panel--2x.panel--kind-details.panel--visible > div > div.panel__body > div.cols.noindent.pad--tblr-default > div.text.col-3.detail-courseinfo.margin--tiny.text--semibold.text--huge > div.dtl-course-code")

# %%
url = "https://movie.douban.com/"
 
# header = {
#     "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36"
# }
page = requests.Session().get(url, headers=header)
tree = html.fromstring(page.text)

result1 = tree.xpath('//td[@class="title"]//a/text()')
print(result1)
# Out:
# ['我的章鱼老师', '监视资本主义：智能陷阱', '鸣鸟不飞：乌云密布', '剧场版 架空OL日记', '杀掉它，然后离开这个小镇', '福冈', '夺冠', '我和我的家乡', '棒球少女', '姜子牙']

# %%
/html/body/main/div[3]/div/div[2]/div[1]/div[1]/div
/html/body/main/div[3]/div/div[2]/div[1]/div[1]/div

# %%
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjM6IjE4MSI7fQ==
/html/body/div/div/div[2]/div[2]/div/div[2]/div/section[3]/div/dl[1]/dd[2]/div[1]/a/text()
/html/body/div/div/div[2]/div[2]/div/div[2]/div/section[3]/div/dl[1]/dd[3]/div[1]/a/text()

# %%
import requests
from lxml import html
url='http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjM6IjE4MSI7fQ==/' #需要爬数据的网址
page=requests.Session().get(url) 
tree=html.fromstring(page.content)
result=tree.xpath('//body/div/div/div[2]/div[2]/div/div[2]/div/section[3]/div/dl[1]/dd[2]/div[1]/a/text()')    
print(result)
# Out:
# ['\r\n\t\t\t\t\t\t\tCS 130R: Selected Programming Languages\r\n\t\t\t\t\t\t']

# %%
http://catalog.college.emory.edu/department-program/index.php
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjIiO30=
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjEiO30=
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjMiO30=
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjQiO30=    
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjUiO30=    
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjYiO30=
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjciO30=    
    
    
    
    
    
http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjM6IjE4MSI7fQ==/
    /html/body/div/div/div[2]/div[2]/div/div[2]/div/section[3]/div/dl[1]/dd[1]/div[1]/a/text()

# %%
import requests
from lxml import html
url='http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjQiO30=/' #需要爬数据的网址
page=requests.Session().get(url) 
# tree=html.fromstring(page.text) 
tree=html.fromstring(page.content)
result=tree.xpath('//*[@id="department-sidebar-listing"]/dd[6]/a//*')    
print(result)
# Out:
# []

# %%
# tutorial: https://stackoverflow.com/questions/38570411/how-to-scrape-href-with-python-3-5-and-beautifulsoup
import urllib.request
from bs4 import BeautifulSoup

theurl = "http://catalog.college.emory.edu/department-program/index.php?YToxOntzOjI6ImlkIjtzOjE6IjQiO30=/"
thepage = urllib.request.urlopen(theurl)

soup = BeautifulSoup(thepage)
project_href = [i['href'] for i in soup.find_all('dd[6]/a', href=True)]
print(project_href)
# Out:
# []

# %%
# tutorial: https://programminghistorian.org/en/lessons/intro-to-beautiful-soup#application-extracting-names-and-urls-from-an-html-page
from bs4 import BeautifulSoup
import csv

# soup = BeautifulSoup (open("43rd-congress.html"), features="lxml")
theurl = "http://catalog.college.emory.edu/department-program/index.php/"
thepage = urllib.request.urlopen(theurl)
soup = BeautifulSoup(thepage)

final_link = soup.p.a
final_link.decompose()

f = csv.writer(open("href_catalog.csv", "w"))
f.writerow(["Department", "Link"])    # Write column headers as the first line

links = soup.find_all('a')
for link in links:
    names = link.contents[0]
    fullLink = link.get('href')
    print(fullLink)
    f.writerow([names,fullLink])
# Out:
# ../index.html
# #
# #
# #main-content
# None
# http://www.college.emory.edu/
# http://oxford.emory.edu/
# http://goizueta.emory.edu/
# http://www.nursing.emory.edu/
# http://www.ece.emory.edu/
# http://www.emory.edu/home/academics/continuing-education.html
# http://precollege.emory.edu/
# http://goizueta.emory.edu/
# http://www.gs.emory.edu/
# http://www.law.emory.edu/
# http://www.med.emory.edu/
# http://www.nursing.emory.edu/
# http://www.sph.emory.edu/
# http://www.candler.emory.edu/
# None
# http://web.library.emory.edu/
# http://business.library.emory.edu/
# http://web.library.emory.edu/about/libraries/other-libraries/chemistry-library/
# http://health.library.emory.edu/
# http://library.law.emory.edu/
# http://marbl.library.emory.edu/
# http://web.library.emory.edu/about/libraries/woodruff-building/music-media-library.html
# http://oxford.library.emory.edu/
# http://www.pitts.emory.edu/
# https://ereserves.library.emory.edu/reserves2/index.php
# ...

# %%
import requests
import json

data = "{\"group\":\"code:CS 130R\",\"key\":\"\",\"srcdb\":\"5209\",\"matched\":\"crn:6447,6448,6459\"}"

def get_page():
    r = requests.get('https://atlas.emory.edu/api/?page=fose&route=details',
                data = data)
    content = r.content.decode("utf-8")
    return json.loads(content)

cs130 = get_page()

# %%
newdic = {}
newdic['CourseID'] = cs130['code']
newdic['CourseName'] = cs130['title']
newdic['semester'] = cs130['crse_typoff_html']
newdic['all_sections'] = cs130['all_sections']
newdic['allInGroup'] = cs130['allInGroup']
newdic['allInGroup'][0]
for course in newdic['allInGroup']:
    print(course)
# Out:
# {'key': '3399', 'code': 'CS 130R', 'title': 'Selected Programming Languages: Programming in Python', 'crn': '6447', 'no': '1', 'total': '3', 'schd': 'LEC', 'stat': 'A', 'isCancelled': '', 'meets': 'MW 1-1:50p', 'mpkey': '3651', 'meetingTimes': '[{"meet_day":"0","start_time":"1300","end_time":"1350"},{"meet_day":"2","start_time":"1300","end_time":"1350"}]', 'instr': 'J. Jeong', 'start_date': '2020-08-19', 'end_date': '2020-11-24', 'enrl_stat': 'O', 'srcdb': '5209'}
# {'key': '3400', 'code': 'CS 130R', 'title': 'Selected Programming Languages: Programming in Python', 'crn': '6448', 'no': '2', 'total': '3', 'schd': 'LEC', 'stat': 'A', 'isCancelled': '', 'meets': 'TTh 1-1:50p', 'mpkey': '2435', 'meetingTimes': '[{"meet_day":"1","start_time":"1300","end_time":"1350"},{"meet_day":"3","start_time":"1300","end_time":"1350"}]', 'instr': 'T. Santos', 'start_date': '2020-08-19', 'end_date': '2020-11-24', 'enrl_stat': 'O', 'srcdb': '5209'}
# ...

# %%
# this is a benchmark
payload = get_payload('a')

courseCode = {} # get a dict with course code and crn
for course in payload['results']: # payload['results'] is a list of dict
    #course is a dict
    code = course['code']
    crn = course['crn']
    if code in courseCode:
        courseCode[code].append(crn)
    else:
        courseCode[code] = []
        courseCode[code].append(crn)
        
new_courseCode = {} # get a neat version of the dict containing course code and crn
for i in courseCode: # i is course code
    crns = courseCode[i] # crns is a list
    new_crn = ','.join(crns)
    new_courseCode[i] = new_crn

req = [] # get the request string
for i in new_courseCode:
    req.append("{\"group\":\"code:" + i + "\",\"key\":\"\",\"srcdb\":\"5209\",\"matched\":\"crn:"+new_courseCode[i]+"\"}")


course = get_page(req[0]) # type: dict

newdic = {} # containing all course data
newdic['courseCode'] = course['code']
newdic['courseTitle'] = course['title']
newdic['semester'] = course['crse_typoff_html']
newdic['sessions'] = course['allInGroup'] # all sessions
for session in newdic['allInGroup']:
    print(session)

# %%
# Bench 2
import requests
import json
from progress.bar import Bar


code = "code:CS 130R"
srcdb = "5209"
matched = "crn:6447,6448,6459"
# data = "{\"group\":\"{}\",\"key\":\"\",\"srcdb\":\"{}\",\"matched\":\"{}\"}".format(code,srcdb,matched)
# data = "{\"group\":\"code:CS 130R\",\"key\":\"\",\"srcdb\":\"5209\",\"matched\":\"crn:6447,6448,6459\"}"
# data = req[0]

def get_payload(search_word):
    r = requests.get('https://atlas.emory.edu/api/?page=fose&route=search&keyword={}'.format(search_word),data = "{\"other\":{\"srcdb\":\"5209\"},\"criteria\":[{\"field\":\"keyword\",\"value\":\"a\"}]}")
    content = r.content.decode("utf8")
    # print(type(content))
    json_c = json.loads(content)
#     print(json_c["results"])
    return json_c

def get_page(request):
    r = requests.get('https://atlas.emory.edu/api/?page=fose&route=details',
                data = request)
    content = r.content.decode("utf-8")
    return json.loads(content)

payload = get_payload('cs')

courseCode = {} # get a dict with course code and crn
for course in payload['results']: # payload['results'] is a list of dict
    #course is a dict
    code = course['code']
    crn = course['crn']
    if code in courseCode:
        courseCode[code].append(crn)
    else:
        courseCode[code] = []
        courseCode[code].append(crn)
        
new_courseCode = {} # get a neat version of the dict containing course code and crn
for i in courseCode: # i is course code
    crns = courseCode[i] # crns is a list
    new_crn = ','.join(crns)
    new_courseCode[i] = new_crn

req = [] # get the request string
for i in new_courseCode:
    req.append("{\"group\":\"code:" + i + "\",\"key\":\"\",\"srcdb\":\"5209\",\"matched\":\"crn:"+new_courseCode[i]+"\"}")

# %%
import time, random
import requests
def get_page(request):
    requests.adapters.DEFAULT_RETRIES = 5 # Increase the number of reconnections
    s = requests.session()
    s.keep_alive = False # Close redundant connections
    r = s.get('https://atlas.emory.edu/api/?page=fose&route=details',
                data = request)
    content = r.content.decode("utf-8")
    return json.loads(content)

total_courses = {} # containing all course data
print("Total number of requests:", len(req))
start = time.time()
for re in req:
    time.sleep(random.random()*3)
    try:
        print("|", sep=' ', end='', flush=True)
        course = get_page(re)
        newdic = {}
        newdic['courseCode'] = course['code']
        newdic['courseTitle'] = course['title']
        newdic['semester'] = course['crse_typoff_html']
        newdic['sessions'] = course['allInGroup'] # all sessions of a course
        total_courses[course['code']] = newdic
    except:
        print("Connection refused by the server..")
        print("ZZzzzz...")
        time.sleep(random.random()*5)
        print("Was a nice sleep, now let me continue...")
        continue

      
end = time.time()
timeElapse = end - start
print("timeElapse:", timeElapse)
print(newdic)
# Out:
# |||||||||||||||||||||||||||||Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# |||||||||||||||||||||||||||||||||||Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# |||||Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# |||||||||||||||Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# |||||||||||||||||||||||||||||||||||||||||||Connection refused by the server..
# Let me sleep for 5 seconds
# ZZzzzz...
# Was a nice sleep, now let me continue...
# |||||||||||||||||||||||||||||||||||||||

# %%
# This is the actual scrawler
import requests
import json

code = "code:CS 130R"
srcdb = "5209"
matched = "crn:6447,6448,6459"
# data = "{\"group\":\"{}\",\"key\":\"\",\"srcdb\":\"{}\",\"matched\":\"{}\"}".format(code,srcdb,matched)
# data = "{\"group\":\"code:CS 130R\",\"key\":\"\",\"srcdb\":\"5209\",\"matched\":\"crn:6447,6448,6459\"}"
# data = req[0]

def get_payload(search_word):
    r = requests.get('https://atlas.emory.edu/api/?page=fose&route=search&keyword={}'.format(search_word),data = "{\"other\":{\"srcdb\":\"5209\"},\"criteria\":[{\"field\":\"keyword\",\"value\":\"a\"}]}")
    content = r.content.decode("utf8")
    # print(type(content))
    json_c = json.loads(content)
#     print(json_c["results"])
    return json_c

def get_page(request):
    r = requests.get('https://atlas.emory.edu/api/?page=fose&route=details',
                data = request)
    content = r.content.decode("utf-8")
    return json.loads(content)

payload = get_payload('a')

courseCode = {} # get a dict with course code and crn
for course in payload['results']: # payload['results'] is a list of dict
    #course is a dict
    code = course['code']
    crn = course['crn']
    if code in courseCode:
        courseCode[code].append(crn)
    else:
        courseCode[code] = []
        courseCode[code].append(crn)
        
new_courseCode = {} # get a neat version of the dict containing course code and crn
for i in courseCode: # i is course code
    crns = courseCode[i] # crns is a list
    new_crn = ','.join(crns)
    new_courseCode[i] = new_crn

req = [] # get the request string
for i in new_courseCode:
    req.append("{\"group\":\"code:" + i + "\",\"key\":\"\",\"srcdb\":\"5209\",\"matched\":\"crn:"+new_courseCode[i]+"\"}")

newdic = {} # containing all course data
for re in req:
    course = get_page(re)
    newdic['courseCode'] = course['code']
    newdic['courseTitle'] = course['title']
    newdic['semester'] = course['crse_typoff_html']
    newdic['sessions'] = course['allInGroup'] # all sessions of a course

newdic
# Out:
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1662                     if errno != 0:
# -> 1663                         raise SysCallError(errno, errorcode.get(errno))
#    1664                 raise SysCallError(-1, "Unexpected EOF")
#
# ...

# %%
courseCode = {}
for course in payload['results']: # payload['results'] is a list of dict
    #course is a dict
    code = course['code']
    crn = course['crn']
    if code in courseCode:
        courseCode[code].append(crn)
    else:
        courseCode[code] = []
        courseCode[code].append(crn)
        
courseCode
# Out:
# {'BIOL 264': ['3671', '3672', '3673', '3674', '3675'],
#  'DM 700': ['5098'],
#  'GH 572': ['1697'],
#  'IBS 590': ['5250'],
#  'NRSG 425': ['4224'],
#  'NRSG 457D': ['4780'],
#  'NRSG 707D': ['4309'],
#  'PAE 7100': ['1075'],
#  'PAE 7106': ['1087'],
#  'PSYC 777R': ['5502'],
#  'SOC 599R': ['1449'],
#  'THEA 322': ['4367', '4366'],
#  'AAS 247': ['1768', '4859'],
#  'AAS 385': ['1766', '1770', '1772', '1920', '2314', '2769', '4882'],
#  'AAS 385W': ['4720', '5889'],
#  'AAS 398R': ['5162', '6249'],
#  'AAS 495A': ['3643', '3667', '5585', '5587'],
#  'ACT 210': ['2132', '2131', '2133', '2134', '2135'],
#  'ACT 211': ['2136', '2137', '2138'],
#  'ACT 312A': ['2139', '2140'],
#  'ACT 512': ['5223', '5225', '1573', '1575', '1577'],
#  'ACT 513': ['4759'],
#  'ACT 513A': ['4760'],
#  'ACT 516': ['1647', '1648'],
#  'ACT 580': ['5116'],
#  'ACT 612A': ['1625', '1626'],
#  'ACT 680': ['1622'],
#  'ACT 710': ['1907'],
#  'AEPI 515D': ['1734', '1736'],
#  'AEPI 538D': ['1752'],
# ...

# %%
import json
new_courseCode = {}
for i in courseCode: # i is course code
    crns = courseCode[i] # crns is a list
    new_crn = ','.join(crns)
    new_courseCode[i] = new_crn

# new_courseCode

"{\"group\":\"code:CS 130R\",\"key\":\"\",\"srcdb\":\"5209\",\"matched\":\"crn:6447,6448,6459\"}"
'{"group":"code:BIOL 264","key":"","srcdb":"5209","matched":"crn:3671,3672,3673,3674,3675"}'
req = []

for i in new_courseCode:
    req.append("{\"group\":\"code:" + i + "\",\"key\":\"\",\"srcdb\":\"5209\",\"matched\":\"crn:"+new_courseCode[i]+"\"}")

# %%
req[0]
# Out:
# '{"group":"code:BIOL 264","key":"","srcdb":"5209","matched":"crn:3671,3672,3673,3674,3675"}'
